# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    'name':['Sarfraz', 'Saurabh', 'Ashraf', 'Irfan', 'Sadik'],
    'marks':[80, 83, 82, 85, 90],
    'city':['Mumbai', 'Kolkata', 'Bareily', 'Lucknow', 'Vikroli']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks     city
# 0  Sarfraz     80   Mumbai
# 1  Saurabh     83  Kolkata
# 2   Ashraf     82  Bareily
# 3    Irfan     85  Lucknow
# 4    Sadik     90  Vikroli

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv', index=False)

# %%
df.head(2)
# Out:
#       name  marks     city
# 0  Sarfraz     80   Mumbai
# 1  Saurabh     83  Kolkata

# %%
df.tail(2)
# Out:
#     name  marks     city
# 3  Irfan     85  Lucknow
# 4  Sadik     90  Vikroli

# %%
df.describe()
# Out:
#            marks
# count   5.000000
# mean   84.000000
# std     3.807887
# min    80.000000
# 25%    82.000000
# 50%    83.000000
# 75%    85.000000
# max    90.000000

# %%
lok = pd.read_csv('train.csv')

# %%
lok
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Train no Passengers  \
# 0             0             0             0           0     12310    Sarfraz
# 1             1             1             1           1     12312     Junaid
# 2             2             2             2           2     12313      Irfan
# 3             3             3             3           3     12314      Sadik
# 4             4             4             4           4     12315     Suhail
#
#       City         State
# 0   Mumbai   Maharashtra
# 1  Lucknow  Uttarpradesh
# 2     Pune   Maharashtra
# 3  Vikroli   Maharashtra
# 4   Kanpur  Uttarpradesh

# %%
lok['Train no'][0]=12310
# Out:
# C:\Users\Lenovo ThinkPad T460\AppData\Local\Temp\ipykernel_9552\911810231.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lok['Train no'][0]=12310

# %%
lok
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Train no Passengers  \
# 0             0             0             0           0     12310    Sarfraz
# 1             1             1             1           1     12312     Junaid
# 2             2             2             2           2     12313      Irfan
# 3             3             3             3           3     12314      Sadik
# 4             4             4             4           4     12315     Suhail
#
#       City         State
# 0   Mumbai   Maharashtra
# 1  Lucknow  Uttarpradesh
# 2     Pune   Maharashtra
# 3  Vikroli   Maharashtra
# 4   Kanpur  Uttarpradesh

# %%
lok.to_csv('train.csv')

# %%
lok.index=['first','second','third','fourth','fifth']

# %%
lok
# Out:
#         Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Train no  \
# first              0             0             0           0     12310
# second             1             1             1           1     12312
# third              2             2             2           2     12313
# fourth             3             3             3           3     12314
# fifth              4             4             4           4     12315
#
#        Passengers     City         State
# first     Sarfraz   Mumbai   Maharashtra
# second     Junaid  Lucknow  Uttarpradesh
# third       Irfan     Pune   Maharashtra
# fourth      Sadik  Vikroli   Maharashtra
# fifth      Suhail   Kanpur  Uttarpradesh

# %%
ser = pd.Series(np.random.rand(5))

# %%
type(ser)
ser
# Out:
# 0    0.350328
# 1    0.406268
# 2    0.562770
# 3    0.282342
# 4    0.798666
# dtype: float64

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index=np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.219317  0.824946  0.817691  0.982314  0.827392
# 1  0.224720  0.693313  0.006512  0.025118  0.366556
# 2  0.415095  0.969219  0.030915  0.891687  0.027335
# 3  0.374867  0.524318  0.956194  0.627921  0.100751
# 4  0.117855  0.940793  0.057273  0.664033  0.609887

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0
#
# [334 rows x 5 columns]

# %%
newdf[0]
# Out:
# 0      4.0
# 1      4.0
# 2      4.0
# 3      4.0
# 4      4.0
#       ...
# 329    4.0
# 330    4.0
# 331    4.0
# 332    4.0
# 333    4.0
# Name: 0, Length: 334, dtype: float64

# %%
newdf.loc[1,2]=9.00000

# %%
newdf
# Out:
#        0         1         2         3         4
# 0    4.0  0.015941  0.928109  0.622355  0.222152
# 1    4.0  0.720891  9.000000  0.971509  0.629111
# 2    4.0  0.597572  0.940201  0.835095  0.235284
# 3    4.0  0.682900  0.816188  0.643941  0.279807
# 4    4.0  0.075485  0.965147  0.961936  0.586807
# ..   ...       ...       ...       ...       ...
# 329  4.0  0.809205  0.949227  0.022241  0.905369
# 330  4.0  0.287483  0.440234  0.052449  0.618073
# 331  4.0  0.952007  0.168746  0.137484  0.174047
# 332  4.0  0.988308  0.364175  0.865838  0.058645
# 333  4.0  0.239028  0.601043  0.766299  0.281786
#
# [334 rows x 5 columns]

# %%
newdf.columns=list('ABCDE')

# %%
newdf
# Out:
#        A         B         C         D         E
# 0    4.0  0.015941  0.928109  0.622355  0.222152
# 1    4.0  0.720891  9.000000  0.971509  0.629111
# 2    4.0  0.597572  0.940201  0.835095  0.235284
# 3    4.0  0.682900  0.816188  0.643941  0.279807
# 4    4.0  0.075485  0.965147  0.961936  0.586807
# ..   ...       ...       ...       ...       ...
# 329  4.0  0.809205  0.949227  0.022241  0.905369
# 330  4.0  0.287483  0.440234  0.052449  0.618073
# 331  4.0  0.952007  0.168746  0.137484  0.174047
# 332  4.0  0.988308  0.364175  0.865838  0.058645
# 333  4.0  0.239028  0.601043  0.766299  0.281786
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,'A']=600

# %%
newdf
# Out:
#          A         B         C         D         E
# 0    600.0  0.015941  0.928109  0.622355  0.222152
# 1      4.0  0.720891  9.000000  0.971509  0.629111
# 2      4.0  0.597572  0.940201  0.835095  0.235284
# 3      4.0  0.682900  0.816188  0.643941  0.279807
# 4      4.0  0.075485  0.965147  0.961936  0.586807
# ..     ...       ...       ...       ...       ...
# 329    4.0  0.809205  0.949227  0.022241  0.905369
# 330    4.0  0.287483  0.440234  0.052449  0.618073
# 331    4.0  0.952007  0.168746  0.137484  0.174047
# 332    4.0  0.988308  0.364175  0.865838  0.058645
# 333    4.0  0.239028  0.601043  0.766299  0.281786
#
# [334 rows x 5 columns]

# %%
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  9.000000  0.971509
# 2  0.940201  0.835095

# %%
newdf.loc[:,['C','D']]
# Out:
#             C         D
# 0    0.928109  0.622355
# 1    9.000000  0.971509
# 2    0.940201  0.835095
# 3    0.816188  0.643941
# 4    0.965147  0.961936
# ..        ...       ...
# 329  0.949227  0.022241
# 330  0.440234  0.052449
# 331  0.168746  0.137484
# 332  0.364175  0.865838
# 333  0.601043  0.766299
#
# [334 rows x 2 columns]

# %%
newdf.loc[[1,2],:]
# Out:
#      A         B         C         D         E
# 1  4.0  0.720891  9.000000  0.971509  0.629111
# 2  4.0  0.597572  0.940201  0.835095  0.235284

# %%
newdf.loc[(newdf['A']<5) & (newdf['C']>0.8)]
# Out:
#        A         B         C         D         E
# 1    4.0  0.720891  9.000000  0.971509  0.629111
# 2    4.0  0.597572  0.940201  0.835095  0.235284
# 3    4.0  0.682900  0.816188  0.643941  0.279807
# 4    4.0  0.075485  0.965147  0.961936  0.586807
# 5    4.0  0.231955  0.824497  0.562046  0.238149
# ..   ...       ...       ...       ...       ...
# 311  4.0  0.548678  0.917668  0.206832  0.891352
# 315  4.0  0.555695  0.809438  0.398671  0.594019
# 316  4.0  0.994421  0.920069  0.861374  0.292210
# 328  4.0  0.658859  0.862550  0.508042  0.004202
# 329  4.0  0.809205  0.949227  0.022241  0.905369
#
# [63 rows x 5 columns]

# %%
newdf.head(2)
# Out:
#        A         B         C         D         E
# 0  600.0  0.015941  0.928109  0.622355  0.222152
# 1    4.0  0.720891  9.000000  0.971509  0.629111

# %%
newdf.iloc[0,4]
# Out:
# 0.22215187433136563

# %%
newdf.iloc[[0,5],[1,2]]
# Out:
#           B         C
# 0  0.015941  0.928109
# 5  0.231955  0.824497

# %%
newdf.head(3)
# Out:
#        A         B         C         D         E
# 0  600.0  0.015941  0.928109  0.622355  0.222152
# 1    4.0  0.720891  9.000000  0.971509  0.629111
# 2    4.0  0.597572  0.940201  0.835095  0.235284

# %%
newdf.drop([0])
# Out:
#        A         B         C         D         E
# 1    4.0  0.720891  9.000000  0.971509  0.629111
# 2    4.0  0.597572  0.940201  0.835095  0.235284
# 3    4.0  0.682900  0.816188  0.643941  0.279807
# 4    4.0  0.075485  0.965147  0.961936  0.586807
# 5    4.0  0.231955  0.824497  0.562046  0.238149
# ..   ...       ...       ...       ...       ...
# 329  4.0  0.809205  0.949227  0.022241  0.905369
# 330  4.0  0.287483  0.440234  0.052449  0.618073
# 331  4.0  0.952007  0.168746  0.137484  0.174047
# 332  4.0  0.988308  0.364175  0.865838  0.058645
# 333  4.0  0.239028  0.601043  0.766299  0.281786
#
# [333 rows x 5 columns]

# %%
newdf.drop(['E'],axis=1, inplace=True)

# %%
newdf
# Out:
#          A         B         C         D
# 0    600.0  0.015941  0.928109  0.622355
# 1      4.0  0.720891  9.000000  0.971509
# 2      4.0  0.597572  0.940201  0.835095
# 3      4.0  0.682900  0.816188  0.643941
# 4      4.0  0.075485  0.965147  0.961936
# ..     ...       ...       ...       ...
# 329    4.0  0.809205  0.949227  0.022241
# 330    4.0  0.287483  0.440234  0.052449
# 331    4.0  0.952007  0.168746  0.137484
# 332    4.0  0.988308  0.364175  0.865838
# 333    4.0  0.239028  0.601043  0.766299
#
# [334 rows x 4 columns]

# %%
newdf.drop([0],axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 newdf.drop([0],axis=1, inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4809 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4810 def drop(
#    4811     self,
#    (...)
# ...

# %%
newdf

# %%
newdf.drop([1,5],axis=0, inplace=True)

# %%
newdf.head(3)

# %%
newdf.reset_index(drop=True, inplace=True)

# %%
newdf.head(3)

# %%
newdf['B'].isnull()

# %%
newdf.loc[:,['A']] =None

# %%
newdf.head(3)

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
})

# %%
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates(subset=['brand'], keep=False)
# Out:
# Empty DataFrame
# Columns: [brand, style, rating]
# Index: []

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   brand   5 non-null      object
#  1   style   5 non-null      object
#  2   rating  5 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 248.0+ bytes

# %%
df['brand'].value_counts(dropna=False)
# Out:
# Indomie    3
# Yum Yum    2
# Name: brand, dtype: int64

# %%
df.notnull()
# Out:
#    brand  style  rating
# 0   True   True    True
# 1   True   True    True
# 2   True   True    True
# 3   True   True    True
# 4   True   True    True
